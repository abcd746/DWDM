# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

import warnings
warnings.filterwarnings('ignore')

df = pd.read_excel("weathers.xlsx")
df
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high      0  yes
# 1   overcast        cool   normal      1  yes
# 2   overcast        mild     high      1  yes
# 3   overcast         hot   normal      0  yes
# 4      rainy        mild     high      0  yes
# 5      rainy        cool   normal      0  yes
# 6      rainy        cool   normal      1  yes
# 7      rainy        mild     high      0   no
# 8      rainy        mild     high      1   no
# 9      sunny         hot     high      0   no
# 10     sunny         hot     high      0   no
# 11     sunny        mild     high      1   no
# 12     sunny        cool   normal      1  yes
# 13     sunny        mild   normal      1  yes
# 14     rainy        cool     high      1  yes
# 15     sunny         hot   normal      0   no
# 16     sunny         hot   normal      0  yes
# 17     rainy        cool     high      1  yes
# 18  overcast        mild   normal      0  yes
# 19  overcast        mild   normal      0   no
# 20  overcast        mild   normal      1   no

# %%
df1=df.dropna()
df1
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high      0  yes
# 1   overcast        cool   normal      1  yes
# 2   overcast        mild     high      1  yes
# 3   overcast         hot   normal      0  yes
# 4      rainy        mild     high      0  yes
# 5      rainy        cool   normal      0  yes
# 6      rainy        cool   normal      1  yes
# 7      rainy        mild     high      0   no
# 8      rainy        mild     high      1   no
# 9      sunny         hot     high      0   no
# 10     sunny         hot     high      0   no
# 11     sunny        mild     high      1   no
# 12     sunny        cool   normal      1  yes
# 13     sunny        mild   normal      1  yes
# 14     rainy        cool     high      1  yes
# 15     sunny         hot   normal      0   no
# 16     sunny         hot   normal      0  yes
# 17     rainy        cool     high      1  yes
# 18  overcast        mild   normal      0  yes
# 19  overcast        mild   normal      0   no
# 20  overcast        mild   normal      1   no

# %%
df1["outlook"].replace({"overcast":1, "rainy":2, "sunny":3},inplace=True)

df1["temperature"].replcae({"mild":0,"hot":1,"cool":2},inplace=True)

df1["humidity"].replace({"high":0,"normal":1},inplace=True)

df1["play"].replace({"no":0,"yes":1},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-3cbfccb1919c> in <cell line: 3>()
#       1 df1["outlook"].replace({"overcast":1, "rainy":2, "sunny":3},inplace=True)
#       2
# ----> 3 df1["temperature"].replcae({"mild":0,"hot":1,"cool":2},inplace=True)
#       4
#       5 df1["humidity"].replace({"high":0,"normal":1},inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'replcae'
